# %% [markdown]
# ![BDAA_Logo.png](attachment:BDAA_Logo.png)

# %% [markdown]
# # Intro to Web Scraping - Topic II Practice

# %% [markdown]
# ## Importing and setting up

# %%
# Import all needed modules
from bs4 import BeautifulSoup # BeautifulSoup is an HTML parser
import urllib.request # requests.get allows us to connect to a website through Python
import pandas as pd # Pandas is a general data management module
import re # String cleanup
import matplotlib.pyplot as plt # For quick data visualizations
